# %% [markdown]
# # Exctract meaning of ethnicity code

# %%
import pandas as pd
from tqdm import tqdm
from src.converter import converter

# %%
actor_df = pd.read_csv('data/actor_data.csv', index_col=0)
test_sample = actor_df[:50]
test_sample
# Out:
#                      Actor date of birth Actor gender  Actor height  \
# Actor name
# denzel_washington             1954-12-28            M          1.84
# matt_damon                    1970-10-08            M          1.78
# tom_hanks                     1956-07-09            M          1.83
# eddie_murphy                  1961-04-03            M          1.75
# tom_cruise                    1962-07-03            M          1.70
# ...                                  ...          ...           ...
# dan_castellaneta              1957-10-29            M          1.78
# eva_mendes                    1974-03-05            F          1.68
# ben_affleck                   1972-08-15            M          1.89
# john_michael_higgins          1963-02-12            M          1.80
# michael_j._fox                1961-06-09            M          1.63
#
#                      Actor ethnicity  Actor age at movie release  \
# Actor name
# denzel_washington            /m/0x67                        26.0
# matt_damon                /m/0cnvdq1                        18.0
# tom_hanks                 /m/02p4q5p                        27.0
# eddie_murphy                 /m/0x67                        21.0
# tom_cruise                 /m/02ctzb                        18.0
# ...                              ...                         ...
# dan_castellaneta                 NaN                        32.0
# eva_mendes                 /m/04dbw3                        24.0
# ben_affleck                /m/07bch9                        19.0
# john_michael_higgins             NaN                        34.0
# michael_j._fox             /m/0g8_vp                        24.0
#
#                       Actor Score Index
# Actor name
# denzel_washington             10.000000
# matt_damon                     9.912690
# tom_hanks                      9.741555
# eddie_murphy                   9.415060
# tom_cruise                     9.362255
# ...                                 ...
# dan_castellaneta               6.566376
# eva_mendes                     6.563597
# ben_affleck                    6.562301
# john_michael_higgins           6.554449
# michael_j._fox                 6.527429
#
# [100 rows x 6 columns]

# %%
tqdm.pandas() # for progress_apply

test_sample.loc[:, 'Actor ethnicity'] = test_sample['Actor ethnicity'].progress_apply(converter.get_ethnicity)
test_sample
# Out:
# 100%|██████████| 100/100 [00:15<00:00,  6.38it/s]
#                      Actor date of birth Actor gender  Actor height  \
# Actor name
# denzel_washington             1954-12-28            M          1.84
# matt_damon                    1970-10-08            M          1.78
# tom_hanks                     1956-07-09            M          1.83
# eddie_murphy                  1961-04-03            M          1.75
# tom_cruise                    1962-07-03            M          1.70
# ...                                  ...          ...           ...
# dan_castellaneta              1957-10-29            M          1.78
# eva_mendes                    1974-03-05            F          1.68
# ben_affleck                   1972-08-15            M          1.89
# john_michael_higgins          1963-02-12            M          1.80
# michael_j._fox                1961-06-09            M          1.63
#
#                              Actor ethnicity  Actor age at movie release  \
# Actor name
# denzel_washington          African Americans                        26.0
# matt_damon            Scandinavian Americans                        18.0
# tom_hanks               Portuguese Americans                        27.0
# eddie_murphy               African Americans                        21.0
# tom_cruise                      White people                        18.0
# ...                                      ...                         ...
# dan_castellaneta                        None                        32.0
# eva_mendes                   Cuban Americans                        24.0
# ben_affleck               Scottish Americans                        19.0
# john_michael_higgins                    None                        34.0
# michael_j._fox            Canadian Americans                        24.0
#
#                       Actor Score Index
# Actor name
# denzel_washington             10.000000
# matt_damon                     9.912690
# tom_hanks                      9.741555
# eddie_murphy                   9.415060
# tom_cruise                     9.362255
# ...                                 ...
# dan_castellaneta               6.566376
# eva_mendes                     6.563597
# ben_affleck                    6.562301
# john_michael_higgins           6.554449
# michael_j._fox                 6.527429
#
# [100 rows x 6 columns]

# %%
print(len(converter.ethnicity_data))
# Out:
# 35
