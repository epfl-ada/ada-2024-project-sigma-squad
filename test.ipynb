# %%
import pandas as pd
from src.data import clean_actor_data

# %%
first_actors = pd.read_csv('first_actors.csv', index_col=0)

clean_actor_data(first_actors)
first_actors
# Out:
# Converting ethnicity entity IDs...
# 100%|██████████| 5/5 [00:00<00:00, 21664.79it/s]
#                   Gender  Height               Ethnicity  \
# Actor name
# Denzel Washington      M    1.84       African Americans
# Matt Damon             M    1.78  Scandinavian Americans
# Tom Hanks              M    1.83    Portuguese Americans
# Eddie Murphy           M    1.75       African Americans
# Tom Cruise             M    1.70            White people
#
#                    Age at First Release  Success Score           University  \
# Actor name
# Denzel Washington                    26      10.000000  Fordham University
# Matt Damon                           18       9.912690   Harvard University
# Tom Hanks                            27       9.741555      sub 1500 school
# Eddie Murphy                         21       9.415060           Did not go
# Tom Cruise                           18       9.362255           Did not go
#
#                    Theater      Sports  Number of Children  Birth Year  \
# Actor name
# Denzel Washington     True  Basketball                   4        1954
# Matt Damon            True         NaN                   4        1970
# Tom Hanks             True         NaN                   4        1956
# Eddie Murphy         False         NaN                  10        1961
# Tom Cruise           False    Football                   3        1962
#
#                   Birth Month Birth Region  found_match
# Actor name
# Denzel Washington    December          USA         True
# Matt Damon            October          USA         True
# Tom Hanks                July          USA        False
# Eddie Murphy            April          USA        False
# Tom Cruise               July          USA        False
