# %%
import pandas as pd
import numpy as np

# %%
actor_df = pd.read_csv('actor_data_for_regression.csv')
actor_df
# Out:
#       Unnamed: 0         Actor name Gender  Height               Ethnicity  \
# 0              0  Denzel Washington      M   1.840       African Americans
# 1              1         Matt Damon      M   1.780  Scandinavian Americans
# 2              2          Tom Hanks      M   1.830    Portuguese Americans
# 3              3       Eddie Murphy      M   1.750       African Americans
# 4              4         Tom Cruise      M   1.700            White people
# ...          ...                ...    ...     ...                     ...
# 6534        6534  Lindsay Hollister      F   1.750                     NaN
# 6535        6535    Terrence Howard      M   1.840       African Americans
# 6536        6536            Madonna      F   1.613        French Canadians
# 6537        6537       Evelyn Keyes      F   1.630                     NaN
# 6538        6538        Peter Fonda      M   1.910         Dutch Americans
#
#       Age at First Release  Success Score                University  Theater  \
# 0                     26.0      10.000000  Specialised Drama School     True
# 1                     18.0       9.912690        Harvard University     True
# 2                     27.0       9.741555           sub 1500 school     True
# 3                     21.0       9.415060                Did not go    False
# 4                     18.0       9.362255                Did not go    False
# ...                    ...            ...                       ...      ...
# 6534                  30.0       1.103153          Miami University    False
# 6535                  26.0       0.915104                Did not go    False
# 6536                  26.0       0.838557                Did not go    False
# 6537                  72.0       0.700949                Did not go    False
# 6538                  41.0       0.000000           sub 1500 school     True
#
#           Sports  ... Birth Year Birth Month  QS University Rank  Ranked Uni  \
# 0     Basketball  ...     1954.0    December          Not Ranked           0
# 1      No Sports  ...     1970.0     October                   4           1
# 2      No Sports  ...     1956.0        July          Not Ranked           0
# 3      No Sports  ...     1961.0       April          Not Ranked           0
# 4       Football  ...     1962.0        July          Not Ranked           0
# ...          ...  ...        ...         ...                 ...         ...
# 6534   No Sports  ...     1977.0        June                1201           1
# 6535       Track  ...     1969.0       March          Not Ranked           0
# 6536   No Sports  ...     1958.0      August          Not Ranked           0
# 6537   No Sports  ...     1916.0    November          Not Ranked           0
# 6538       Dance  ...     1940.0    February          Not Ranked           0
#
#      Usable Uni Rank Specialised Drama School  Specialised Acting School  \
# 0               3000                        1                          0
# 1                  4                        0                          0
# 2               3000                        0                          0
# 3               3000                        0                          0
# 4               3000                        0                          0
# ...              ...                      ...                        ...
# 6534            1201                        0                          0
# 6535            3000                        0                          0
# 6536            3000                        0                          0
# 6537            3000                        0                          0
# 6538            3000                        0                          0
#
#       Specialised Dance School  Specialised Arts School  Birth Region
# 0                            0                        0           USA
# 1                            0                        0           USA
# 2                            0                        0           USA
# 3                            0                        0           USA
# 4                            0                        0           USA
# ...                        ...                      ...           ...
# 6534                         0                        0           USA
# 6535                         0                        0           USA
# 6536                         0                        0           USA
# 6537                         0                        0           USA
# 6538                         0                        0           USA
#
# [6539 rows x 23 columns]

# %%
import plotly.express as px

fig = px.histogram(
    actor_df, 
    x='Age at First Release', 
    color='Gender', 
    nbins=50, 
    title='Age at First Movie Appearance by Gender',
    labels={'Age at First Release': 'Age'},
    opacity=0.7,
    width=800, height=600
)
fig.update_layout(barmode='overlay', xaxis_title='Age at First Release', yaxis_title='Count')

fig.show()

# %%
fig = px.histogram(
    actor_df, 
    x='Height', 
    color='Gender', 
    nbins=50, 
    title='Height by Gender',
    labels={'Height': 'Height'},
    opacity=0.7,
    width=800, height=600
)
fig.update_layout(barmode='overlay', xaxis_title='Height', yaxis_title='Count')

fig.show()

# %%
fig = px.scatter(
    actor_df,
    x="Age at First Release",
    y="Success Score",
    color="Gender",
    trendline="ols",  # Add a linear regression line
    title="Age at First Release vs. Success Score",
    hover_data=["Actor name"]
)

fig.show()
